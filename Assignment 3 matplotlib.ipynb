# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
#PLot a single Python List
plt.plot([2, 6, 8, 17]);

# %%
X = [22, 88, 98, 103, 45]
y = [7, 8, 9, 10, 11]

# %%
#Plot X & Y (the lists you've created)
plt.plot(X, y);

# %%
fig, ax = plt.subplots()

# %%
fig, ax = plt.subplots()
ax.plot(X, y);

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

X = [34, 77, 21, 54, 9]
y = [9, 45, 89, 66, 4]

fig, ax = plt.subplots()

ax.plot(X, y)

ax.set(title="Sample simple plot", xlabel="x-axis", ylabel="y-axis")
# Out:
# [Text(0, 0.5, 'y-axis'),
#  Text(0.5, 0, 'x-axis'),
#  Text(0.5, 1.0, 'Sample simple plot')]

# %%
import numpy as np

# %%
X = np.linspace(0, 10, 100)

# %%
fig, ax = plt.subplots()
ax.plot(X, X**2);

# %%
#Create a scatter plot of X versus the exponential of X
fig, ax = plt.subplots()
ax.scatter(X, np.exp(X));

# %%
fig, ax = plt.subplots()
ax.scatter(X, np.sin(X));

# %%
favorite_food_prices = {"Almond butter": 10, "Blueberries": 5, "Eggs": 6}

# %%
fig, ax = plt.subplots()
ax.bar(favorite_food_prices.keys(), favorite_food_prices.values())

#Food title 

ax.set(title="Ashray's favorite foods", xlabel="Food", ylabel="Price ($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(favorite_food_prices.keys()), list(favorite_food_prices.values()))

ax.set(title="Ashray's favorite foods", xlabel="Price ($)", ylabel="Food");

# %%
X = np.random.randn(1000)

# Create a histogram plot of X
fig, ax = plt.subplots()
ax.hist(X);

# %%
X = np.random.random(1000)

fig, ax = plt.subplots()
ax.hist(X);

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10, 5))

ax1.plot(X, X/2)

ax2.scatter(np.random.random(10), np.random.random(10))

ax3.bar(favorite_food_prices.keys(), favorite_food_prices.values())

ax4.hist(np.random.randn(1000));

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-83bf2f29b5a6> in <module>
# ----> 1 car_sales["Price"].plot()
#
# ~/Desktop/sample-project/env/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~/Desktop/sample-project/env/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ...

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "")

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()

# %%
car_sales["Sale Date"] = pd.date_range("13/1/2020", periods=len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   4000         4000 2020-01-13
# 1   Honda    Red          87899      4   5000         9000 2020-01-14
# 2  Toyota   Blue          32549      3   7000        16000 2020-01-15
# 3     BMW  Black          11179      5  22000        38000 2020-01-16
# 4  Nissan  White         213095      4   3500        41500 2020-01-17
# 5  Toyota  Green          99213      4   4500        46000 2020-01-18
# 6   Honda   Blue          45698      4   7500        53500 2020-01-19
# 7   Honda   Blue          54738      4   7000        60500 2020-01-20
# 8  Toyota  White          60000      4   6250        66750 2020-01-21
# 9  Nissan  White          31600      4   9700        76450 2020-01-22

# %%
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
X = np.random.rand(10, 4)

df= pd.DataFrame(X, columns=["a", "b", "c", "d"])

df.plot(kind="bar");

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Price"].plot.hist(bins=20);

# %%
heart_disease = pd.read_csv("../sample-project/heart-disease.csv")

# %%
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
heart_disease["age"].plot.hist(bins=50);

# %%
heart_disease.plot.hist(subplots=True);

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %%
over_50 = heart_disease[heart_disease["age"] > 50]

fig, ax = plt.subplots(figsize=(10, 6))

scatter = ax.scatter(over_50["age"], over_50["chol"], c=over_50["target"])

ax.set(title="Heart Disease and Choolestrol Levels", xlabel="Age", ylabel="Cholestrol");

ax.legend(*scatter.legend_elements(), title="Target")

ax.axhline(over_50["chol"].mean(), linestyle="--");

# %%
plt.style.available
# Out:
# ['seaborn-bright',
#  'seaborn',
#  'seaborn-poster',
#  'seaborn-pastel',
#  'seaborn-darkgrid',
#  'seaborn-dark',
#  'dark_background',
#  'ggplot',
#  'seaborn-paper',
#  'seaborn-whitegrid',
#  'classic',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  'fast',
#  'seaborn-notebook',
#  '_classic_test',
#  'grayscale',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-muted',
#  'seaborn-deep',
#  'seaborn-white',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-colorblind',
#  'bmh']

# %%
plt.style.use("seaborn")

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");
ax.legend(*scatter.legend_elements(), title="Target")

# Add a meanline
ax.axhline(over_50["chol"].mean(),
           linestyle="--");

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"],
                     cmap="winter") # changed cmap parameter

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");
ax.legend(*scatter.legend_elements(), title="Target")

# Add a meanline
ax.axhline(over_50["chol"].mean(),
           linestyle="--",
           color="red"); # changed color parameter

# %%
fig.ax = plt.subplots()
